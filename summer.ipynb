# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
df=pd.read_csv('summer.csv')
print("Summer olympics is held on",len(df['City'].unique()),"cities.")
# Out:
# ('Summer olympics is held on', 22, 'cities.')

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df_gold = df[df['Medal'] == 'Gold']

df_gold.groupby('Sport').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize = (10,5), color = 'orange')

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
df.groupby('Sport').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize = (10,5), color='red')

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df.groupby('Athlete').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize = (10,5), color = 'orange')

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df_gold = df[df['Medal'] == 'Gold']

df_gold.groupby('Athlete').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize = (10,5), color='red')

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df_india = df[df['Country'] == 'IND']
df_gold = df_india[df['Medal'] == 'Gold']
df_gold.min()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Year                              1928
# City                         Amsterdam
# Sport                           Hockey
# Discipline                      Hockey
# Athlete                AHKTAR, Hussain
# Country                            IND
# Gender                             Men
# Event         10M Air Rifle (60 Shots)
# Medal                             Gold
# dtype: object

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
df.groupby('Event').count()['Athlete'].sort_values(ascending = False).head().plot.bar(figsize = (10,5), color = 'orange')

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df_women = df[df['Gender'] == 'Women']
df_gold = df_women[df['Medal'] == 'Gold']
df_gold

df_gold.groupby('Sport').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize = (10,5), color = 'red')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
